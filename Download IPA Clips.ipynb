.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0270.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0271.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0272.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0273.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0274.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0275.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0276.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0278.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0279.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/027A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/027B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/027D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/027E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0280.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0281.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0282.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0283.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0284.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0288.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0289.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/028A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/028B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/028C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/028D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/028E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/028F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0290.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0291.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0292.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0294.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0295.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0298.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0299.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/029B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/029C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/029D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/029F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02A1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02A2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02B0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02B2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02B7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02BC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02C8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02CC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02D0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02D1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02DE.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E4.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E5_02E9.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E6.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E7_02E5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E7_02E6_02E8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E9.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E9_02E5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/02E9_02E7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0300.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0301.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0302.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0303.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0304.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0306.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0308.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/030B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/030C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/030F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0318.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0319.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/031A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/031C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/031D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/031E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/031F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0320.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0324.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0325.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0329.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/032A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/032C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/032F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0330.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0334.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0339.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/033A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/033B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/033C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/033D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/035C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/0361.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/03B2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/03B8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/03C7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/1DC4.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/1DC5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/1DC8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/2016.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/203F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/207F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/2197.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/2198.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/2C71.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/A71B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JW/A71C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/002E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0061.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0062.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0063.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0064.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0065.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0066.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0068.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0069.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006B_02BC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/006F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0070.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0070_02BC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0071.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0072.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0073.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0073_02BC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0074.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0074_02BC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0075.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0076.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0077.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0078.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0079.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/007A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/007C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/00E6.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/00E7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/00F0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/00F8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0127.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/014B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0153.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/01C0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/01C1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/01C2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/01C3.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0250.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0251.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0252.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0253.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0254.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0255.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0256.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0257.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0258.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0259.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/025B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/025C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/025E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/025F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0260.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0261.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0262.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0263.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0264.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0265.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0266.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0267.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0268.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/026A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/026C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/026D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/026E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/026F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0270.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0271.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0272.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0273.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0274.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0275.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0276.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0278.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0279.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/027A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/027B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/027D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/027E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0280.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0281.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0282.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0283.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0284.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0288.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0289.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/028A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/028B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/028C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/028D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/028E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/028F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0290.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0291.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0292.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0294.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0295.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0298.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0299.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/029B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/029C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/029D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/029F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02A1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02A2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02B0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02B2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02B7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02BC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02C8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02CC.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02D0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02D1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02DE.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E0.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E1.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E4.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E5_02E9.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E6.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E7_02E5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E7_02E6_02E8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E9.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E9_02E5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/02E9_02E7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0300.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0301.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0302.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0303.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0304.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0306.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0308.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/030B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/030C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/030F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0318.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0319.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/031A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/031C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/031D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/031E.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/031F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0320.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0324.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0325.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0329.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/032A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/032C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/032F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0330.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0334.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0339.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/033A.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/033B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/033C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/033D.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/035C.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/0361.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/03B2.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/03B8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/03C7.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/1DC4.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/1DC5.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/1DC8.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/2016.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/203F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/207F.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/2197.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/2198.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/2C71.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/A71B.mp3',
'https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/PL/A71C.mp3']

# %%
import os
import requests
from urllib.parse import urlparse

urls = URLs

# Base directory to save downloaded files
download_directory = "C:/Github/phone-cleaner/phoneme-Samples/IPA"

# Create base directory if it doesn't exist
if not os.path.exists(download_directory):
    os.makedirs(download_directory)

def download_file(url):
    # Parse the URL to get the path and file name
    parsed_url = urlparse(url)
    path = parsed_url.path.lstrip('/')
    local_filename = os.path.join(download_directory, path)

    # Check if the file already exists
    if os.path.exists(local_filename):
        print(f"File already exists: {local_filename}")
        return

    # Create necessary directories
    os.makedirs(os.path.dirname(local_filename), exist_ok=True)

    # Send HTTP request to the URL
    with requests.get(url, stream=True) as response:
        response.raise_for_status()
        # Save the file locally
        with open(local_filename, 'wb') as file:
            for chunk in response.iter_content(chunk_size=8192):
                file.write(chunk)
    print(f"Downloaded: {local_filename}")

# Download each file
for url in urls:
    try:
        download_file(url)
    except Exception as e:
        print(f"Failed to download {url}: {e}")

print("All downloads completed.")
# Out:
# Downloaded: C:/Github/phone-cleaner/phoneme-Samples/IPA\IPAcharts/inter_chart_2018/sounds/JH/0325_3.mp3
# Downloaded: C:/Github/phone-cleaner/phoneme-Samples/IPA\IPAcharts/inter_chart_2018/sounds/JW/0325_3.mp3
# All downloads completed.

# %%
URLs = ['https://www.internationalphoneticassociation.org/IPAcharts/inter_chart_2018/sounds/JE/