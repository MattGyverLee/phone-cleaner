# %% [markdown]
# # Init

# %%
import panphon
import panphon.distance
ft = panphon.FeatureTable()
dst = panphon.distance.Distance()

# %% [markdown]
# # Feature Tables

# %%
ft.word_array(['syl', 'son', 'cont'], u'sɑlti')

# %% [markdown]
# # Edit distance:

# %%
dst.weighted_feature_edit_distance(u'p',u'b')
# These only differ in voicing.
# Out:
# 0.25

# %%
dst.weighted_feature_edit_distance(u'ɡb',u'b')
# These are very different because /gb/ is interpreted as /g/ and /b/ side by side.
# Out:
# 7.25

# %%
len(ft.word_fts(u'ɡb'))
#See, this has 2 segments.
# Out:
# 2

# %%
dst.dolgo_prime_distance(u'ɡ͡b',u'b')
# Out:
# 1

# %%
dst.feature_edit_distance(u'ɡ͡b',u'b')
# Out:
# 0.08333333333333333

# %%
dst.weighted_feature_edit_distance(u'ɡ͡b',u'b')
# Out:
# 1.0

# %%
word = ft.ipa_segs(u'ɡ͡bb')
print(word)
wordFt = ft.word_fts(u'ɡ͡bb')
for seg in wordFt:
        print(seg)
        
print("\nDifference: ")
print(wordFt[0].differing_specs(wordFt[1]))

print("Same: ")
print(wordFt[0].intersection(wordFt[1]))
# Out:
# ['ɡ͡b', 'b']
# <Segment [-syl, -son, +cons, -cont, -delrel, -lat, -nas, 0strid, +voi, -sg, -cg, 0ant, -cor, 0distr, +lab, +hi, -lo, 0back, -round, -velaric, 0tense, -long, 0hitone, 0hireg]>
# <Segment [-syl, -son, +cons, -cont, -delrel, -lat, -nas, 0strid, +voi, -sg, -cg, +ant, -cor, 0distr, +lab, -hi, -lo, -back, -round, -velaric, 0tense, -long, 0hitone, 0hireg]>
#
# Difference:
# ['ant', 'hi', 'back']
# Same:
# <Segment [-syl, -son, +cons, -cont, -delrel, -lat, -nas, 0strid, +voi, -sg, -cg, -cor, 0distr, +lab, -lo, -round, -velaric, 0tense, -long, 0hitone, 0hireg]>

# %% [markdown]
# You would think that /gb/ and /b/ would be similar sounds, but the above code rates it at 7.5, this is because /g/ and /b/ are counted as 2 separate segements and the g must be added at great cost. The correct version is double articulation /ɡ͡b/ which only has a distance of 1 from /b/.

# %% [markdown]
# # Matrix

# %%
Segs = ft.ipa_segs(u'ɡ͡b b m')
for seg in Segs:
        print(seg)
from itertools import combinations
a = combinations(Segs, 2) 
y = [' '.join(i) for i in a]
print(y)

# %% [markdown]
# # Set Type of Distance

# %% [markdown]
# ## Menu of Sets: Pick one

# %%
# Basic Test
array_of_strings = ['ɡ͡b', 'b', 'm', 'bʷː', 'bː', 'bʷ', 'b̤', 'bʰ', 't', 'tʰ']

# %%
# A messy set with some equivalent values.
array_of_strings = ['b', 'ɡ͡b', 'bː', 'b̤', 'bʷ', 'b̰', 'b͡v', 'bʰ', 'bʷ', 'ˀb', 'bˠ', 'bˤ', 'bˀ', 'bʷː', 'b̤ʲ', 'bʷˠ', 'b̤ː', 'bʷ', 'ɡ͡bː', 'b͡β', 'bˤː', 'ɡ͡bˤ', 'ˀɡ͡b', 'bʲː']

# %%
# A Clean set of "b's".
kǂʔ','kǃh','kǃkxʼ','kǃʔ','kʘ','kʘh','kʘkxʼ','kʘx','kʘʔ','kʘʰ','pʼkxʼ','qǀ','qǀʼ','qǁ','qǁʼ','qǂ','qǂʼ','qǃ','qǃʼ','qʘ','qʘʼ','tʼkxʼ','t̪x','t̪ʼkxʼ','ŋʘ','ŋ̊ǀ','ŋ̊ǁ','ŋ̊ǂ','ŋ̊ǃ','ŋ̊ʘ','ɡǀkxʼ','ɡǀkʰ','ɡǀx','ɡǁ','ɡǁkxʼ','ɡǁkʰ','ɡǁx','ɡǂkxʼ','ɡǂkʰ','ɡǃkxʼ','ɡǃkʰ','ɡʘ','ɡʘkxʼ','ɡʘkʰ','ɡʘx','ɡʼkxʼ','ɢǀ','ɢǀqʰ','ɢǁ','ɢǁqʰ','ɢǂ','ɢǃ','ɢǃqʰ','ɢʘ','ɢʱ','ʔŋǀ','ʔŋǁ','ʔŋǂ','ʔŋǃ','ʔŋʘ','aᴱ','eˤ','oˤ','oᴱ','uᴱ','d̠ʒxʼ','d̠ʒʰ','kǀxʼ','kǀʰʼ','kǁxʼ','kǁʰʼ','kǁʼ','kǃxʼ','kǃʰʼ','kǃʼ','k‼','k‼x','k‼xʼ','k‼ʰ','k‼ʰʼ','k‼ʼ','qm','qn','tʰʼ','t̠ʃx','ŋǀʱ','ŋǃʱ','ŋ‼','ŋ‼ʱ','ɡǀxʼ','ɡǀʱ','ɡǁxʼ','ɡǃxʼ','ɡǃʱ','ɡ‼','ɡ‼x','ɡ‼xʼ','ɡ‼ʱ','ʼm','ʼn','ʼŋǀ','ʼŋǃ','õˤ','ũˤ','bβ','pɸ','nθ','ŋʱ','ɗʲ','˥˨˧','˧˥˨','ɒ̃ː','t̪ʃ|t̠ʃ','eɘ','oɘ','øɘ','œi','œu','ɘi','ɪ̝','ɪ̝ː','cçʼ','hʼ','b͉','ˀb͉','kpr','ɡbr','dɾ','ndɾ','tɾ','ðː','006A+0303','0072+0303','0077+0303','0061+0303+02D0','0065+0303+02D0','0069+0303+02D0','006F+0303+02D0','0075+0303+02D0','0254+0303+02D0','025B+0303+02D0','β̃','ɖɽ','ɳɖɽ','ʈɽ','r̪ː','tʲʼ','i̞','i̞ː','u̞','u̞ː','ɔ̝','ɔ̝ː','ɛ̝','ɛ̝ː','ɸʰ','ɸː','nɬ','nɮ','ŋkx','0078+02B7','0266','0266+02B7','mpʲ','km','ɡm','m̥p','m̥ʰ','å','0072+032A','0064+007A','0068+02B7','kɡ','dᶣ','t̪ʼː','ɓ̥ː','028A','hʷʲ','lʷʲ','nʷʲ','ɡʷʲ','ɾʷʲ','bvʷ','mpf','j̥ʷ','tɕʷ','ŋʷʲ','ʍʲ','ˀc','ˀk','ˀkp','ˀs','ˀɡb','ˀɡʷ','ˀʃʷ','ˀʍ','ˀʍʲ','st','ʃt','bzʷ','dlʷ','n̤ʷ','psʷ','psʷʰ','ɖʐʷ','ɬʷ','ʈʂʷ','ʐʷ','006E+0064+0072','006E+0064+007A','0295','˥˨
s̪ʷ','s̪ʷʲ','t̪s̪ʲʰ','t̪s̪ʲʼ','t̪s̪ʷ','t̪s̪ʷʰ','t̪s̪ʷʲ','t̪s̪ʷʲʰ','t̪s̪ʷʲʼ','t̪s̪ʷʼ','t̪ʲʼ','t̪ʷʰ','t̪ʷʲ','t̪ʷʲʰ','t̪ʷʲʼ','t̪ʷʼ','z̪ʷ','χʷʲ','d͇z͇','nd͇z͇','nt͇s͇ʰ','s͇','t͇s͇','t͇s͇ʰ','ɳʈɽ̥ʰ','ʈɽ̥','ʈɽ̥ʰ','y̠','ø̠̞','ɤ̝','aːi̯','iæ̃','iɛ̃','iɜ','uæ','uɛ̃','uɜ','yĩ','yɜ','ħ̃ʲ','ɟ̥ʝ̥','ãɛ̃','œ̃ɛ̃','ɔ̟̜ː','ɔ̟̜̃ː','ɔ̟̜̰','ɛ̃ːi̯','ɞ̜','ɞ̜ː','ɞ̜̃ː','ɞ̜̰','ɨ̞ː','ɨ̞̃ː','ɨ̞̰','ʉ̃ː','ʉ̰','iɑu','uɑi','y̯ø','d̠ʓ','t̠ʆ','t̠ʆʰ','ɯo','ʉ̟ː','ĩẽ','õã','ɹ̪̰̩','yo','cʰː','qχʰ','ii','iɐ','ua̟','uɐ','ɑ̆','ɛa̟','ɛɐ','i̯ɛ̃','u̯ã','u̯ɔ','u̯ɔ̃','u̯ə̃','u̯ɛ̃','ð̺̞','θ̻','øɪ̯','ʏi̯','ɵ̞̰','ĩã','ĩõ','ʐʲ','ḭː','ṵː','y̰ː','œ̰ː','ɑ̰ː','ɔ̰ː','ɛ̰ː','ɯ̰̽ː','kxʰː','dz̻','ɥ̊','ãũ̯','b˞','k˞','k˞ʰ','l̪̊','n̪̊','p˞','p˞ʰ','ɡ˞','ɻ̊','ɜi̯','çʰ','əo','ð͇ˠ','ə̹','aːu̯','u̯ɔː','øy̯','øːy̯','ɒːi̯','aə','əɨ','ø̞̜','ø̞̜ː','ẽɪ̃','ũã','u̠u','ɛ̃ũ','ɪ̃ə̃','iɪ̯','ɖ̻ʐ̻','ʂ̻','ʈ̻ʂ̻','ʐ̻','ũ̯','ɘ̟','ʼb','ʼd','ʼɡ','ʼɣ','aːi','sʲʰ','ã̤','y̰','ø̰','ɘ̆','ɤ̞̆','ɯɪ̯','ɵ̆','aːɪ','ɑʊ̯','ðʼ','ɮʼ','ʃ̞','ʃ̞ʼ','uœ','ȵ','ȶ͈','ȶ͉','ʈ͈','j̪','ȴ','ȶ','t̪͈','t̪͉','t̺͈','t̺͉','ɺ̺̠','n̪ʷ','ȴʷ','ȵʷ','ȶʷ','ɳʷ','ʈʷ','r̺͈']

# %% [markdown]
# ## Options: Pick one

# %%
allowComplex = True
allowDiacritics = True
verbose = False

# %%
allowComplex = True
allowDiacritics = False

# %%
allowComplex = False
allowDiacritics = True

# %%
allowComplex = False
allowDiacritics = False

# %%
exportImages = False

# %%
exportImages = True

# %% [markdown]
# ## Cleanup

# %%
import unicodedata
import re
from ipapy import UNICODE_TO_IPA
from ipapy import is_valid_ipa

def distance(str1, str2):
    # Function to compute Levenshtein distance between two strings
 
    
    if choice == 1:
        dist = float(dst.weighted_feature_edit_distance(str1,str2))
    elif choice == 2:
        dist = float(dst.feature_edit_distance(str1,str2))
    elif choice == 3:
        dist = float(dst.dolgo_prime_distance(str1,str2))
        #This is less powerful. Do not use.
    elif choice == 4:
        dist =  float(dst.hamming_feature_edit_distance(str1,str2))
    elif choice == 5:
        dist = float(dst.min_edit_distance(str1,str2))
    if (dist == 0) and (str1 != str2):
        pass
        #print('Errorː ', str1 + " and " + str2 + ' are the same!')
    return dist

# Default Choice
choice = 1

def remove_diacritics(input_string):
    # Create an empty string to store the result
    result = ''

    for char in input_string:
        # Use the 'NFKD' normalization form to separate diacritics
        normalized_char = unicodedata.normalize('NFD', char)
        
        # Check if the character is a diacritic (non-spacing mark)
        if not unicodedata.combining(normalized_char):
            result += char

    return result

def remove_accents(input_str):
    nfd_form = unicodedata.normalize('NFD', input_str)
    
    # nodia = u"".join([c for c in nfd_form if not unicodedata.combining(c)])
    return nodia

def prefilter(inPhone):
    phone = unicodedata.normalize("NFD", inPhone)
    phone = phone.replace(u'g', u'ɡ')
    phone = phone.replace(u'd̥', u"t")
    phone = phone.replace(u"ɡ̥", u"k")
    phone = phone.replace(u"R", u"ʀ")
    phone = phone.replace(u"b̥", u"p")
    phone = phone.replace(u"'", u"ʼ")
    phone = phone.replace(u":", u"ː")
    pattern = re.compile(r'[\u02E5-\u02E9]')
    phone = pattern.sub('', phone)
    if not allowDiacritics:
        phone = remove_diacritics(phone)
        #phone = re.sub(r'\\p{M}', '', phone)
    if inPhone != phone and verbose:
        print('Warningː Corrected |' + inPhone + '| to |'  + phone + '|.')
    return phone

def validatePhone (phone):
    if ft.validate_word(phone):
        return True
    else:
        return False 

def testTiebars(phone, inSet):
    count_base_characters = 0
    base_character_index = 0
    # Find the position of the first base character
    for i, c in enumerate(phone):
        if not unicodedata.combining(c):
            count_base_characters += 1
            if count_base_characters >= 2:
                base_character_index = i
                break

    if base_character_index > 0:
        # Insert the tiebar character before the second base character
        # Trying to add a tiebar
        diacritic = "͡"
        modified_phone = phone[:base_character_index] + diacritic + phone[base_character_index:]
        if ft.validate_word(modified_phone):
            inSet.add(modified_phone)
            print('Modification Successful: ' + modified_phone)
        else:
            diacritic = "͜"
            modified_phone = phone[:base_character_index] + diacritic + phone[base_character_index:]
            if ft.validate_word(modified_phone):
                inSet.add(modified_phone)
                print('Modification Successful: ' + modified_phone)


clean_set = set() 
junk = set()
print("Starting with " + str(len(array_of_strings)) + ' phones.')
for phone in array_of_strings:
    
    ## Cleaning Phoible Mess ##
    if ('+' in phone) or (phone[0].isdigit()):
        chars = phone = phone.split('+')
        newphone = ""
        for char in chars:
            newphone = newphone + chr(int(char, 16))
        phone = newphone
        #print(phone)
    phone = prefilter(phone)
    if "|" in phone:
        if verbose:
            print("Splitting:" + phone)
        phones = phone.split('|')
        for option in phones:
            if validatePhone(option):
                if len(phone) > 0:
                    clean_set.add(option)
            else:
                testTiebars(option, clean_set) 
    
    feat = ft.ipa_segs(phone)
    if len(feat) > 1:
        count_base_characters = 0
        #print("Testing: "+ phone)
        if not ft.validate_word(phone):
            junk.add(phone)
        else:
            if allowComplex:
                if len(phone) > 0:
                    clean_set.add(phone)
    else:
        if not ft.validate_word(phone):
            junk.add(phone)
            if verbose:
                print("Errorː Panphon says " + phone + " is invalid!")
            
        else:
            if len(phone) > 0:
                clean_set.add(phone)
        
print()
print('Clean complete. Left with ' + str(len(clean_set)) + ' phones.')
# Out:
# Starting with 1158 phones.
#
# Clean complete. Left with 1158 phones.

# %%
print(len(clean_set))
print(clean_set)
# Out:
# 1158
# {'sʼ', 'ħʲ', 'xʀ', 'ɳʈʰ', 'ld', 'a', 'tɬʼ', 'qʼ', 'ɯː', 'ɳɖʐ', 'ɱf', 'ʈɽ', 'ŋkɾ', 'ɡǁkʰ', 'tʑ', 'ɑɯ', 'ɔˤ', 'βˠ', 'ccʼ', 'ʝ', 'dʲ', 'ɡǃ', 'ð', 'β', 'nɦ', 'qχʷˤ', 'tʃʷː', 'kʘh', 'ɔːə', 'pʃʼ', 'ŋǂʰ', 'nɗ', 'nʃʷ', 'lː', 'ɡbˤ', 'tθʼ', 'oi', 'kp', 'βʷ', 'q', 'ʉi', 'œyː', 'nt', 'qn', 'aːi', 'qǃʼ', 'ndzʲ', 'ɢʘ', 'ntʃɾ', 'ia', 'nl', 'ɲcʰ', 'aˀ', 'iɛi', 'dz', 'nz', 'iːɛ', 'zʲː', 'bzʷ', 'ʀʲ', 'qˤʰ', 'br', 'uɔː', 'xʷː', 'ɴq', 'zː', 'ii', 'ɱvɾ', 'ˀkp', 'iɪ', 'ɭʷ', 'nʲ', 'xʷʼ', 'kʼ', 'ʕː', 'kʘʔ', 'pʲː', 'ŋɡmb', 'əˤ', 'mpʰ', 'yø', 'w', 'ŋɡʲ', 'ɛɔ', 'bʷ', 'mpʷ', 'xʲ', 'cʷʰ', 'ŋǀˀ', 'ˀʍ', 'pfʼ', 'œ', 'aːɪ', 'sʲː', 'psʷ', 'tːʃ', 'ɪ', 'kǁx', 'øː', 'iou', 'sʼː', 'ʀʁ', 'uaː', 'bⁿ', 'ɪi', 'əo', 'ɲj', 'tsʷʼ', 'mˠ', 'ɢǂ', 'uɪ', 'uai', 'oo', 'qχʰ', 'ɪɔ', 'qˤ', 'mm', 'qχʼ', 'hː', 'əɪa', 'a˞', 'kǂh', 'tɕʰː', 'ɢǁqʰ', 'ɡbʲ', 'ʕ', 'dⁿ', 'tʼkxʼ', 'hʷ', 'mpɾ', 'ɐɪ', 'bvʷ', 'cʰː', 'ŋm', 'tsʷʰ', 'œy', 'ɹˤ', 'aʊɪ', 'ɒ', 'ɛæː', 'mw', 'ndː', 'ʂʼ', 'tsɦ', 'ɨa', 'oːu', 'oɔ', 'tʼ', 'ɢʷˤ', 'dʑᶣ', 'ʈr', 'ɯʌ', 'ɤ˞', 'ɻː', 'dlʷ', 'ɑʊ', 'ɢʁ', 'tθ
 'ɲʄ', 'ɴɢ', 'iˤæ', 'eɔ', 'sʲʰ', 'tˤʼ', 'yœː', 'uiɛ', 'ʈɹ', 'pm', 'qǂʼ', 'tsʷː', 'ioː', 'pʷ', 'ts', 'ˀɲ', 'ɡʘkʰ', 'ʊˤː', 'ʑᶣ', 'iˀ', 'ŋɣ', 'uo', 'kɡ', 'lʲ', 'ps', 'ɬl', 'bʷː', 'ɔˤː', 'ɱvʲ', 'tʃʷʰ', 'eʊ', 'ndʒ', 'ʒʲ', 'ɲɟ', 'ɡbː', 'ʔj', 'mp', 'tː', 'øʌ', 'ŋmʷ', 'uːe', 'ɥˤ', 'dɦ', 'ɺʲ', 'ɑo', 'ɢǀqʰ', 'tʰ', 'ŋǃʼ', 'ŋhʲ', 'kxʰː', 'ʍw', 'eəɪ', 'nsʰ', 'ʑː', 'ɱfɾ', 'aˤ', 'ɣʷ', 'øːy', 'ieu', 'dˤː', 'ɦ', 'ɖɦ' ...

# %% [markdown]
# # Sort and  Group by Feature Equivalence

# %%
def custom_sort(clean_set):
    return (len(clean_set), clean_set)

# Sort the IPA data and convert it to a list
sorted_ipa = sorted(clean_set, key=custom_sort)

# Convert the sorted IPA data to a list
simple_to_complex = list(sorted_ipa)

# Print the sorted IPA data as a list
#for ipa in simple_to_complex:
#    print(ipa)
    
print('Sorted '+ str(len(simple_to_complex)) + ' phones by length and alphabet.'  )

choice = 1
groups = {}

# Group items by Levenshtein distance
for item in simple_to_complex:
    found_group = None
    for key in groups:
        if distance(item, key) == 0:
            found_group = key
            break

    if found_group is None:
        found_group = item

    if found_group in groups:
        groups[found_group].append(item)
    else:
        groups[found_group] = [item]

# Print the grouped items
for key, group in groups.items():
    print(f"Group with identifier '{key}': {', '.join(group)}")
    
array_of_strings = list(groups.keys())
eq_groups = groups

print('Found ' + str(len(paradigms)) + ' groups with feature equivalence.')
# Out:
# Sorted 1158 phones by length and alphabet.
# Group with identifier 'a': a
# Group with identifier 'b': b
# Group with identifier 'c': c
# Group with identifier 'd': d
# Group with identifier 'e': e
# Group with identifier 'f': f
# Group with identifier 'h': h
# Group with identifier 'i': i
# Group with identifier 'j': j
# Group with identifier 'k': k
# Group with identifier 'l': l
# Group with identifier 'm': m
# Group with identifier 'n': n
# Group with identifier 'o': o
# Group with identifier 'p': p
# Group with identifier 'q': q
# Group with identifier 'r': r
# Group with identifier 's': s
# Group with identifier 't': t
# Group with identifier 'u': u
# Group with identifier 'v': v
# Group with identifier 'w': w
# Group with identifier 'x': x
# Group with identifier 'y': y
# Group with identifier 'z': z
# Group with identifier 'ð': ð
# Group with identifier 'ø': ø
# Group with identifier 'ħ': ħ
# Group with identifier 'ŋ': ŋ
# Group with identifier 'œ': œ
# Group with identifier 'ɐ': ɐ
# Group with identifier 'ɑ': ɑ
# Group with identifier 'ɒ': ɒ
# Group with identifier 'ɓ': ɓ
# Group with identifier 'ɔ': ɔ
# Group with identifier 'ɕ': ɕ
# Group with identifier 'ɖ': ɖ
# Group with identifier 'ɗ': ɗ
# Group with identifier 'ɘ': ɘ
# Group with identifier 'ɛ': ɛ
# Group with identifier 'ɟ': ɟ
# Group with identifier 'ɠ': ɠ
# Group with identifier 'ɡ': ɡ
# Group with identifier 'ɢ': ɢ
# Group with identifier 'ɣ': ɣ
# Group with identifier 'ɤ': ɤ
# Group with identifier 'ɥ': ɥ
# Group with identifier 'ɦ': ɦ
# Group with identifier 'ɧ': ɧ
# Group with identifier 'ɨ': ɨ
# Group with identifier 'ɪ': ɪ
# Group with identifier 'ɫ': ɫ
# Group with identifier 'ɬ': ɬ
# Group with identifier 'ɭ': ɭ
# Group with identifier 'ɮ': ɮ
# Group with identifier 'ɯ': ɯ
# Group with identifier 'ɰ': ɰ
# Group with identifier 'ɱ': ɱ
# Group with identifier 'ɲ': ɲ
# Group with identifier 'ɳ': ɳ
# Group with identifier 'ɴ': ɴ
# Group with identifier 'ɶ': ɶ
# Group with identifier 'ɸ': ɸ
# Group with identifier 'ɹ': ɹ
# Group with identifier 'ɺ': ɺ
# Group with identifier 'ɻ': ɻ
# Group with identifier 'ɽ': ɽ
# Group with identifier 'ʀ': ʀ
# Group with identifier 'ʁ': ʁ
# Group with identifier 'ʂ': ʂ
# Group with identifier 'ʃ': ʃ
# Group with identifier 'ʄ': ʄ
# Group with identifier 'ʈ': ʈ
# Group with identifier 'ʉ': ʉ
# Group with identifier 'ʊ': ʊ
# Group with identifier 'ʋ': ʋ
# Group with identifier 'ʍ': ʍ
# Group with identifier 'ʎ': ʎ
# Group with identifier 'ʏ': ʏ
# Group with identifier 'ʐ': ʐ
# Group with identifier 'ʑ': ʑ
# Group with identifier 'ʒ': ʒ
# Group with identifier 'ʔ': ʔ
# Group with identifier 'ʕ': ʕ
# Group with identifier 'ʙ': ʙ
# Group with identifier 'ʛ': ʛ
# Group with identifier 'ʝ': ʝ
# Group with identifier 'ʟ': ʟ
# Group with identifier '˥': ˥
# Group with identifier 'β': β
# Group with identifier 'θ': θ
# Group with identifier 'χ': χ
# Group with identifier 'ae': ae
# Group with identifier 'ai': ai
# Group with identifier 'ao': ao
# Group with identifier 'au': au
# Group with identifier 'ay': ay
# Group with identifier 'aɔ': aɔ
# Group with identifier 'aə': aə
# Group with identifier 'aɛ': aɛ
# Group with identifier 'aɨ': aɨ
# Group with identifier 'aɪ': aɪ
# Group with identifier 'aɯ': aɯ
# Group with identifier 'aʊ': aʊ
# Group with identifier 'aˀ': aˀ
# Group with identifier 'aː': aː
# Group with identifier 'a˞': a˞
# Group with identifier 'aˠ': aˠ
# Group with identifier 'aˤ': aˤ
# Group with identifier 'bm': bm
# Group with identifier 'br': br
# Group with identifier 'bv': bv
# Group with identifier 'bz': bz
# Group with identifier 'bɡ': bɡ
# Group with identifier 'bɦ': bɦ
# Group with identifier 'bʲ': bʲ
# Group with identifier 'bʷ': bʷ
# Group with identifier 'bː': bː
# Group with identifier 'bˠ': bˠ
# Group with identifier 'bˤ': bˤ
# Group with identifier 'bβ': bβ
# Group with identifier 'bⁿ': bⁿ
# Group with identifier 'cc': cc
# Group with identifier 'cn': cn
# Group with identifier 'cɲ': cɲ
# Group with identifier 'cʰ': cʰ
# Group with identifier 'cʷ': cʷ
# Group with identifier 'cʼ': cʼ
# Group with identifier 'cː': cː
# Group with identifier 'dl': dl
# Group with identifier 'dn': dn
# Group with identifier 'dr': dr
# Group with identifier 'dx': dx
# Group with identifier 'dz': dz
# Group with identifier 'dð': dð
# Group with identifier 'dɦ': dɦ
# Group with identifier 'dɮ': dɮ
# Group with identifier 'dʑ': dʑ
# Group with identifier 'dʒ': dʒ
# Group with identifier 'dʲ': dʲ
# Group with identifier 'dʷ': dʷ
# Group with identifier 'dː': dː
# Group with identifier 'dˠ': dˠ
# Group with identifier 'dˤ': dˤ
# Group with identifier 'dᶣ': dᶣ
# Group with identifier 'dⁿ': dⁿ
# Group with identifier 'ea': ea
# Group with identifier 'ei': ei
# Group with identifier 'eo': eo
# Group with identifier 'eu': eu
# Group with identifier 'eɔ': eɔ
# Group with identifier 'eɘ': eɘ
# Group with identifier 'eɛ': eɛ
# Group with identifier 'eɪ': eɪ
# Group with identifier 'eʊ': eʊ
# Group with identifier 'eʌ': eʌ
# Group with identifier 'eˀ': eˀ
# Group with identifier 'eː': eː
# Group with identifier 'e˞': e˞
# Group with identifier 'fɾ': fɾ
# Group with identifier 'fʃ': fʃ
# Group with identifier 'fʰ': fʰ
# Group with identifier 'fʲ': fʲ
# Group with identifier 'fʷ': fʷ
# Group with identifier 'fʼ': fʼ
# Group with identifier 'fː': fː
# Group with identifier 'fˠ': fˠ
# Group with identifier 'hʲ': hʲ
# Group with identifier 'hʷ': hʷ
# Group with identifier 'hˀ': hˀ
# Group with identifier 'hː': hː
# Group with identifier 'hᶣ': hᶣ
# Group with identifier 'ia': ia
# Group with identifier 'ie': ie
# Group with identifier 'ii': ii
# Group with identifier 'io': io
# Group with identifier 'iu': iu
# Group with identifier 'iy': iy
# Group with identifier 'iø': iø
# Group with identifier 'iœ': iœ
# Group with identifier 'iɐ': iɐ
# Group with identifier 'iɑ': iɑ
# Group with identifier 'iɒ': iɒ
# Group with identifier 'iɔ': iɔ
# Group with identifier 'iə': iə
# Group with identifier 'iɛ': iɛ
# Group with identifier 'iɨ': iɨ
# Group with identifier 'iɪ': iɪ
# Group with identifier 'iʊ': iʊ
# Group with identifier 'iˀ': iˀ
# Group with identifier 'iː': iː
# Group with identifier 'jʔ': jʔ
# Group with identifier 'jʷ': jʷ
# Group with identifier 'jˀ': jˀ
# Group with identifier 'jː': jː
# Group with identifier 'jˤ': jˤ
# Group with identifier 'kf': kf
# Group with identifier 'kl': kl
# Group with identifier 'km': km
# Group with identifier 'kp': kp
# Group with identifier 'kx': kx
# Group with identifier 'kŋ': kŋ
# Group with identifier 'kǀ': kǀ
# Group with identifier 'kǁ': kǁ
# Group with identifier 'kǂ': kǂ
# Group with identifier 'kǃ': kǃ
# Group with identifier 'kɡ': kɡ
# Group with identifier 'kɦ': kɦ
# Group with identifier 'kɬ': kɬ
# Group with identifier 'kɾ': kɾ
# Group with identifier 'kʘ': kʘ
# Group with identifier 'kʰ': kʰ
# Group with identifier 'kʼ': kʼ
# Group with identifier 'kː': kː
# Group with identifier 'kˤ': kˤ
# Group with identifier 'kᶣ': kᶣ
# Group with identifier 'ld': ld
# Group with identifier 'lɦ': lɦ
# Group with identifier 'lʔ': lʔ
# Group with identifier 'lʲ': lʲ
# Group with identifier 'lʷ': lʷ
# Group with identifier 'lˀ': lˀ
# Group with identifier 'lː': lː
# Group with identifier 'lˠ': lˠ
# Group with identifier 'lˤ': lˤ
# Group with identifier 'lᶣ': lᶣ
# Group with identifier 'mb': mb
# Group with identifier 'mm': mm
# Group with identifier 'mp': mp
# Group with identifier 'mv': mv
# Group with identifier 'mw': mw
# Group with identifier 'mɓ': mɓ
# Group with identifier 'mɦ': mɦ
# Group with identifier 'mɾ': mɾ
# Group with identifier 'mʲ': mʲ
# Group with identifier 'mʷ': mʷ
# Group with identifier 'mˀ': mˀ
# Group with identifier 'mː': mː
# Group with identifier 'mˠ': mˠ
# Group with identifier 'mˤ': mˤ
# Group with identifier 'nb': nb
# Group with identifier 'nd': nd
# Group with identifier 'nh': nh
# Group with identifier 'nl': nl
# Group with identifier 'nn': nn
# Group with identifier 'nr': nr
# Group with identifier 'ns': ns
# Group with identifier 'nt': nt
# Group with identifier 'nz': nz
# Group with identifier 'nð': nð
# Group with identifier 'nɗ': nɗ
# Group with identifier 'nɟ': nɟ
# Group with identifier 'nɡ': nɡ
# Group with identifier 'nɦ': nɦ
# Group with identifier 'nɬ': nɬ
# Group with identifier 'nɮ': nɮ
# Group with identifier 'nʃ': nʃ
# Group with identifier 'nʒ': nʒ
# Group with identifier 'nʲ': nʲ
# Group with identifier 'nʷ': nʷ
# Group with identifier 'nˀ': nˀ
# Group with identifier 'nː': nː
# Group with identifier 'nˠ': nˠ
# Group with identifier 'nˤ': nˤ
# Group with identifier 'nθ': nθ
# Group with identifier 'oa': oa
# Group with identifier 'oe': oe
# Group with identifier 'oi': oi
# Group with identifier 'oo': oo
# Group with identifier 'ou': ou
# Group with identifier 'oɔ': oɔ
# Group with identifier 'oɘ': oɘ
# Group with identifier 'oɛ': oɛ
# Group with identifier 'oɪ': oɪ
# Group with identifier 'oʊ': oʊ
# Group with identifier 'oʌ': oʌ
# Group with identifier 'oˀ': oˀ
# Group with identifier 'oː': oː
# Group with identifier 'o˞': o˞
# Group with identifier 'pf': pf
# Group with identifier 'pm': pm
# Group with identifier 'ps': ps
# Group with identifier 'pt': pt
# Group with identifier 'pɦ': pɦ
# Group with identifier 'pɸ': pɸ
# Group with identifier 'pɾ': pɾ
# Group with identifier 'pʰ': pʰ
# Group with identifier 'pʲ': pʲ
# Group with identifier 'pʷ': pʷ
# Group with identifier 'pʼ': pʼ
# Group with identifier 'pː': pː
# Group with identifier 'pˠ': pˠ
# Group with identifier 'pˤ': pˤ
# Group with identifier 'qm': qm
# Group with identifier 'qn': qn
# Group with identifier 'qǀ': qǀ
# Group with identifier 'qǁ': qǁ
# Group with identifier 'qǂ': qǂ
# Group with identifier 'qǃ': qǃ
# Group with identifier 'qʘ': qʘ
# Group with identifier 'qʰ': qʰ
# Group with identifier 'qʼ': qʼ
# Group with identifier 'qː': qː
# Group with identifier 'qˤ': qˤ
# Group with identifier 'qχ': qχ
# Group with identifier 'rʲ': rʲ
# Group with identifier 'rʷ': rʷ
# Group with identifier 'rˀ': rˀ
# Group with identifier 'rː': rː
# Group with identifier 'rˠ': rˠ
# Group with identifier 'rˤ': rˤ
# Group with identifier 'rᶣ': rᶣ
# Group with identifier 'st': st
# Group with identifier 'sɾ': sɾ
# Group with identifier 'sʰ': sʰ
# Group with identifier 'sʲ': sʲ
# Group with identifier 'sʷ': sʷ
# Group with identifier 'sʼ': sʼ
# Group with identifier 'sː': sː
# Group with identifier 'sˠ': sˠ
# Group with identifier 'sˤ': sˤ
# Group with identifier 'sθ': sθ
# Group with identifier 'sᶣ': sᶣ
# Group with identifier 'tl': tl
# Group with identifier 'tn': tn
# Group with identifier 'tr': tr
# Group with identifier 'ts': ts
# Group with identifier 'tx': tx
# Group with identifier 'tz': tz
# Group with identifier 'tɕ': tɕ
# Group with identifier 'tɦ': tɦ
# Group with identifier 'tɬ': tɬ
# Group with identifier 'tʃ': tʃ
# Group with identifier 'tʑ': tʑ
# Group with identifier 'tʒ': tʒ
# Group with identifier 'tʙ': tʙ
# Group with identifier 'tʰ': tʰ
# Group with identifier 'tʲ': tʲ
# Group with identifier 'tʷ': tʷ
# Group with identifier 'tʼ': tʼ
# Group with identifier 'tː': tː
# Group with identifier 'tˠ': tˠ
# Group with identifier 'tˤ': tˤ
# Group with identifier 'tθ': tθ
# Group with identifier 'ua': ua
# Group with identifier 'ue': ue
# Group with identifier 'ui': ui
# Group with identifier 'uo': uo
# Group with identifier 'uu': uu
# Group with identifier 'uy': uy
# Group with identifier 'uœ': uœ
# Group with identifier 'uɐ': uɐ
# Group with identifier 'uɑ': uɑ
# Group with identifier 'uɔ': uɔ
# Group with identifier 'uə': uə
# Group with identifier 'uɛ': uɛ
# Group with identifier 'uɨ': uɨ
# Group with identifier 'uɪ': uɪ
# Group with identifier 'uʊ': uʊ
# Group with identifier 'uˀ': uˀ
# Group with identifier 'uː': uː
# Group with identifier 'u˞': u˞
# Group with identifier 'uˤ': uˤ
# Group with identifier 'vɾ': vɾ
# Group with identifier 'vʲ': vʲ
# Group with identifier 'vʷ': vʷ
# Group with identifier 'vː': vː
# Group with identifier 'vˠ': vˠ
# Group with identifier 'vˤ': vˤ
# Group with identifier 'wʲ': wʲ
# Group with identifier 'wˀ': wˀ
# Group with identifier 'wː': wː
# Group with identifier 'wˤ': wˤ
# Group with identifier 'xh': xh
# Group with identifier 'xk': xk
# Group with identifier 'xʀ': xʀ
# Group with identifier 'xʰ': xʰ
# Group with identifier 'xʲ': xʲ
# Group with identifier 'xʷ': xʷ
# Group with identifier 'xʼ': xʼ
# Group with identifier 'xː': xː
# Group with identifier 'ya': ya
# Group with identifier 'ye': ye
# Group with identifier 'yi': yi
# Group with identifier 'yo': yo
# Group with identifier 'yu': yu
# Group with identifier 'yø': yø
# Group with identifier 'yœ': yœ
# Group with identifier 'yə': yə
# Group with identifier 'yɛ': yɛ
# Group with identifier 'yɜ': yɜ
# Group with identifier 'yː': yː
# Group with identifier 'zɾ': zɾ
# Group with identifier 'zʲ': zʲ
# Group with identifier 'zʷ': zʷ
# Group with identifier 'zˀ': zˀ
# Group with identifier 'zː': zː
# Group with identifier 'zˠ': zˠ
# Group with identifier 'zˤ': zˤ
# Group with identifier 'æʉ': æʉ
# Group with identifier 'æʌ': æʌ
# Group with identifier 'ðʲ': ðʲ
# Group with identifier 'ðː': ðː
# Group with identifier 'ðˠ': ðˠ
# Group with identifier 'ðˤ': ðˤ
# Group with identifier 'øu': øu
# Group with identifier 'øy': øy
# Group with identifier 'øɘ': øɘ
# Group with identifier 'øɪ': øɪ
# Group with identifier 'øʌ': øʌ
# Group with identifier 'øː': øː
# Group with identifier 'ħʲ': ħʲ
# Group with identifier 'ħʷ': ħʷ
# Group with identifier 'ħː': ħː
# Group with identifier 'ŋb': ŋb
# Group with identifier 'ŋh': ŋh
# Group with identifier 'ŋk': ŋk
# Group with identifier 'ŋm': ŋm
# Group with identifier 'ŋŋ': ŋŋ
# Group with identifier 'ŋǀ': ŋǀ
# Group with identifier 'ŋǁ': ŋǁ
# Group with identifier 'ŋǂ': ŋǂ
# Group with identifier 'ŋǃ': ŋǃ
# Group with identifier 'ŋɡ': ŋɡ
# Group with identifier 'ŋɣ': ŋɣ
# Group with identifier 'ŋɾ': ŋɾ
# Group with identifier 'ŋʘ': ŋʘ
# Group with identifier 'ŋʷ': ŋʷ
# Group with identifier 'ŋˀ': ŋˀ
# Group with identifier 'ŋː': ŋː
# Group with identifier 'ŋˤ': ŋˤ
# Group with identifier 'œi': œi
# Group with identifier 'œu': œu
# Group with identifier 'œy': œy
# Group with identifier 'œɛ': œɛ
# Group with identifier 'œʌ': œʌ
# Group with identifier 'œʏ': œʏ
# Group with identifier 'œː': œː
# Group with identifier 'ɐi': ɐi
# Group with identifier 'ɐu': ɐu
# Group with identifier 'ɐɪ': ɐɪ
# Group with identifier 'ɐʉ': ɐʉ
# Group with identifier 'ɐʊ': ɐʊ
# Group with identifier 'ɐː': ɐː
# Group with identifier 'ɑe': ɑe
# Group with identifier 'ɑi': ɑi
# Group with identifier 'ɑo': ɑo
# Group with identifier 'ɑu': ɑu
# Group with identifier 'ɑy': ɑy
# Group with identifier 'ɑɔ': ɑɔ
# Group with identifier 'ɑɪ': ɑɪ
# Group with identifier 'ɑɯ': ɑɯ
# Group with identifier 'ɑʊ': ɑʊ
# Group with identifier 'ɑː': ɑː
# Group with identifier 'ɑ˞': ɑ˞
# Group with identifier 'ɒu': ɒu
# Group with identifier 'ɒɯ': ɒɯ
# Group with identifier 'ɒː': ɒː
# Group with identifier 'ɓʲ': ɓʲ
# Group with identifier 'ɓʷ': ɓʷ
# Group with identifier 'ɓː': ɓː
# Group with identifier 'ɔa': ɔa
# Group with identifier 'ɔe': ɔe
# Group with identifier 'ɔi': ɔi
# Group with identifier 'ɔo': ɔo
# Group with identifier 'ɔu': ɔu
# Group with identifier 'ɔy': ɔy
# Group with identifier 'ɔə': ɔə
# Group with identifier 'ɔɛ': ɔɛ
# Group with identifier 'ɔɪ': ɔɪ
# Group with identifier 'ɔʊ': ɔʊ
# Group with identifier 'ɔʏ': ɔʏ
# Group with identifier 'ɔː': ɔː
# Group with identifier 'ɔˤ': ɔˤ
# Group with identifier 'ɕʰ': ɕʰ
# Group with identifier 'ɕʼ': ɕʼ
# Group with identifier 'ɕː': ɕː
# Group with identifier 'ɕᶣ': ɕᶣ
# Group with identifier 'ɖr': ɖr
# Group with identifier 'ɖɦ': ɖɦ
# Group with identifier 'ɖɳ': ɖɳ
# Group with identifier 'ɖɽ': ɖɽ
# Group with identifier 'ɖʐ': ɖʐ
# Group with identifier 'ɖː': ɖː
# Group with identifier 'ɖⁿ': ɖⁿ
# Group with identifier 'ɗʒ': ɗʒ
# Group with identifier 'ɗʲ': ɗʲ
# Group with identifier 'ɗʷ': ɗʷ
# Group with identifier 'ɗː': ɗː
# Group with identifier 'ɘi': ɘi
# Group with identifier 'ɘː': ɘː
# Group with identifier 'əo': əo
# Group with identifier 'əu': əu
# Group with identifier 'əy': əy
# Group with identifier 'əɨ': əɨ
# Group with identifier 'əɪ': əɪ
# Group with identifier 'əɯ': əɯ
# Group with identifier 'əʉ': əʉ
# Group with identifier 'əʊ': əʊ
# Group with identifier 'ə˞': ə˞
# Group with identifier 'əˤ': əˤ
# Group with identifier 'ɛa': ɛa
# Group with identifier 'ɛe': ɛe
# Group with identifier 'ɛi': ɛi
# Group with identifier 'ɛo': ɛo
# Group with identifier 'ɛu': ɛu
# Group with identifier 'ɛɐ': ɛɐ
# Group with identifier 'ɛɔ': ɛɔ
# Group with identifier 'ɛə': ɛə
# Group with identifier 'ɛɪ': ɛɪ
# Group with identifier 'ɛɯ': ɛɯ
# Group with identifier 'ɛʉ': ɛʉ
# Group with identifier 'ɛʊ': ɛʊ
# Group with identifier 'ɛː': ɛː
# Group with identifier 'ɞʏ': ɞʏ
# Group with identifier 'ɟɦ': ɟɦ
# Group with identifier 'ɟʝ': ɟʝ
# Group with identifier 'ɟʷ': ɟʷ
# Group with identifier 'ɟː': ɟː
# Group with identifier 'ɠɓ': ɠɓ
# Group with identifier 'ɠʷ': ɠʷ
# Group with identifier 'ɠː': ɠː
# Group with identifier 'ɡb': ɡb
# Group with identifier 'ɡm': ɡm
# Group with identifier 'ɡv': ɡv
# Group with identifier 'ɡǀ': ɡǀ
# Group with identifier 'ɡǁ': ɡǁ
# Group with identifier 'ɡǂ': ɡǂ
# Group with identifier 'ɡǃ': ɡǃ
# Group with identifier 'ɡɓ': ɡɓ
# Group with identifier 'ɡɣ': ɡɣ
# Group with identifier 'ɡɦ': ɡɦ
# Group with identifier 'ɡɾ': ɡɾ
# Group with identifier 'ɡʘ': ɡʘ
# Group with identifier 'ɡʰ': ɡʰ
# Group with identifier 'ɡː': ɡː
# Group with identifier 'ɡᶣ': ɡᶣ
# Group with identifier 'ɡⁿ': ɡⁿ
# Group with identifier 'ɢǀ': ɢǀ
# Group with identifier 'ɢǁ': ɢǁ
# Group with identifier 'ɢǂ': ɢǂ
# Group with identifier 'ɢǃ': ɢǃ
# Group with identifier 'ɢʁ': ɢʁ
# Group with identifier 'ɢʘ': ɢʘ
# Group with identifier 'ɢː': ɢː
# Group with identifier 'ɢˤ': ɢˤ
# Group with identifier 'ɣv': ɣv
# Group with identifier 'ɣʷ': ɣʷ
# Group with identifier 'ɣˀ': ɣˀ
# Group with identifier 'ɣː': ɣː
# Group with identifier 'ɤi': ɤi
# Group with identifier 'ɤː': ɤː
# Group with identifier 'ɤ˞': ɤ˞
# Group with identifier 'ɥˤ': ɥˤ
# Group with identifier 'ɦʷ': ɦʷ
# Group with identifier 'ɨa': ɨa
# Group with identifier 'ɨi': ɨi
# Group with identifier 'ɨə': ɨə
# Group with identifier 'ɨɛ': ɨɛ
# Group with identifier 'ɨː': ɨː
# Group with identifier 'ɪa': ɪa
# Group with identifier 'ɪe': ɪe
# Group with identifier 'ɪi': ɪi
# Group with identifier 'ɪu': ɪu
# Group with identifier 'ɪɔ': ɪɔ
# Group with identifier 'ɪə': ɪə
# Group with identifier 'ɪɛ': ɪɛ
# Group with identifier 'ɪʌ': ɪʌ
# Group with identifier 'ɪː': ɪː
# Group with identifier 'ɪˤ': ɪˤ
# Group with identifier 'ɫː': ɫː
# Group with identifier 'ɬl': ɬl
# Group with identifier 'ɬʟ': ɬʟ
# Group with identifier 'ɬʲ': ɬʲ
# Group with identifier 'ɬʷ': ɬʷ
# Group with identifier 'ɬʼ': ɬʼ
# Group with identifier 'ɬː': ɬː
# Group with identifier 'ɬˠ': ɬˠ
# Group with identifier 'ɭʷ': ɭʷ
# Group with identifier 'ɭː': ɭː
# Group with identifier 'ɮʲ': ɮʲ
# Group with identifier 'ɯa': ɯa
# Group with identifier 'ɯi': ɯi
# Group with identifier 'ɯo': ɯo
# Group with identifier 'ɯɑ': ɯɑ
# Group with identifier 'ɯə': ɯə
# Group with identifier 'ɯɤ': ɯɤ
# Group with identifier 'ɯɪ': ɯɪ
# Group with identifier 'ɯʌ': ɯʌ
# Group with identifier 'ɯː': ɯː
# Group with identifier 'ɱf': ɱf
# Group with identifier 'ɱv': ɱv
# Group with identifier 'ɱð': ɱð
# Group with identifier 'ɲc': ɲc
# Group with identifier 'ɲj': ɲj
# Group with identifier 'ɲɟ': ɲɟ
# Group with identifier 'ɲɲ': ɲɲ
# Group with identifier 'ɲʄ': ɲʄ
# Group with identifier 'ɲʒ': ɲʒ
# Group with identifier 'ɲʝ': ɲʝ
# Group with identifier 'ɲː': ɲː
# Group with identifier 'ɲᶣ': ɲᶣ
# Group with identifier 'ɳɖ': ɳɖ
# Group with identifier 'ɳɡ': ɳɡ
# Group with identifier 'ɳɦ': ɳɦ
# Group with identifier 'ɳʈ': ɳʈ
# Group with identifier 'ɳʷ': ɳʷ
# Group with identifier 'ɴq': ɴq
# Group with identifier 'ɴɢ': ɴɢ
# Group with identifier 'ɴː': ɴː
# Group with identifier 'ɶː': ɶː
# Group with identifier 'ɸʰ': ɸʰ
# Group with identifier 'ɸʲ': ɸʲ
# Group with identifier 'ɸʷ': ɸʷ
# Group with identifier 'ɸʼ': ɸʼ
# Group with identifier 'ɸː': ɸː
# Group with identifier 'ɹˤ': ɹˤ
# Group with identifier 'ɺʲ': ɺʲ
# Group with identifier 'ɺː': ɺː
# Group with identifier 'ɻʲ': ɻʲ
# Group with identifier 'ɻʷ': ɻʷ
# Group with identifier 'ɻː': ɻː
# Group with identifier 'ʀʁ': ʀʁ
# Group with identifier 'ʀʲ': ʀʲ
# Group with identifier 'ʁː': ʁː
# Group with identifier 'ʂʰ': ʂʰ
# Group with identifier 'ʂʼ': ʂʼ
# Group with identifier 'ʂː': ʂː
# Group with identifier 'ʃt': ʃt
# Group with identifier 'ʃʰ': ʃʰ
# Group with identifier 'ʃʲ': ʃʲ
# Group with identifier 'ʃʷ': ʃʷ
# Group with identifier 'ʃʼ': ʃʼ
# Group with identifier 'ʃː': ʃː
# Group with identifier 'ʃˠ': ʃˠ
# Group with identifier 'ʃˤ': ʃˤ
# Group with identifier 'ʈr': ʈr
# Group with identifier 'ʈɳ': ʈɳ
# Group with identifier 'ʈɹ': ʈɹ
# Group with identifier 'ʈɽ': ʈɽ
# Group with identifier 'ʈʂ': ʈʂ
# Group with identifier 'ʈʰ': ʈʰ
# Group with identifier 'ʈʷ': ʈʷ
# Group with identifier 'ʈʼ': ʈʼ
# Group with identifier 'ʈː': ʈː
# Group with identifier 'ʉi': ʉi
# Group with identifier 'ʉu': ʉu
# Group with identifier 'ʉœ': ʉœ
# Group with identifier 'ʉə': ʉə
# Group with identifier 'ʉɞ': ʉɞ
# Group with identifier 'ʉː': ʉː
# Group with identifier 'ʊa': ʊa
# Group with identifier 'ʊe': ʊe
# Group with identifier 'ʊi': ʊi
# Group with identifier 'ʊu': ʊu
# Group with identifier 'ʊɐ': ʊɐ
# Group with identifier 'ʊɔ': ʊɔ
# Group with identifier 'ʊə': ʊə
# Group with identifier 'ʊɪ': ʊɪ
# Group with identifier 'ʊː': ʊː
# Group with identifier 'ʊˤ': ʊˤ
# Group with identifier 'ʋʲ': ʋʲ
# Group with identifier 'ʋː': ʋː
# Group with identifier 'ʌy': ʌy
# Group with identifier 'ʌə': ʌə
# Group with identifier 'ʌɯ': ʌɯ
# Group with identifier 'ʍw': ʍw
# Group with identifier 'ʍʲ': ʍʲ
# Group with identifier 'ʎː': ʎː
# Group with identifier 'ʏi': ʏi
# Group with identifier 'ʏː': ʏː
# Group with identifier 'ʐʲ': ʐʲ
# Group with identifier 'ʐʷ': ʐʷ
# Group with identifier 'ʑː': ʑː
# Group with identifier 'ʑᶣ': ʑᶣ
# Group with identifier 'ʒʲ': ʒʲ
# Group with identifier 'ʒʷ': ʒʷ
# Group with identifier 'ʒˀ': ʒˀ
# Group with identifier 'ʒː': ʒː
# Group with identifier 'ʒˠ': ʒˠ
# Group with identifier 'ʒˤ': ʒˤ
# Group with identifier 'ʔj': ʔj
# Group with identifier 'ʔw': ʔw
# Group with identifier 'ʔɾ': ʔɾ
# Group with identifier 'ʔʲ': ʔʲ
# Group with identifier 'ʔʷ': ʔʷ
# Group with identifier 'ʔː': ʔː
# Group with identifier 'ʕʷ': ʕʷ
# Group with identifier 'ʕː': ʕː
# Group with identifier 'ʝː': ʝː
# Group with identifier 'ˀy': ˀy
# Group with identifier 'ˀɖ': ˀɖ
# Group with identifier 'ˀɲ': ˀɲ
# Group with identifier 'ˀʍ': ˀʍ
# Group with identifier '˥˦': ˥˦
# Group with identifier 'βʲ': βʲ
# Group with identifier 'βʷ': βʷ
# Group with identifier 'βː': βː
# Group with identifier 'βˠ': βˠ
# Group with identifier 'θʼ': θʼ
# Group with identifier 'θː': θː
# Group with identifier 'χʼ': χʼ
# Group with identifier 'χː': χː
# Group with identifier 'aeˤ': aeˤ
# Group with identifier 'aiː': aiː
# Group with identifier 'aoˤ': aoˤ
# Group with identifier 'auː': auː
# Group with identifier 'aɪː': aɪː
# Group with identifier 'aʊɪ': aʊɪ
# Group with identifier 'aːi': aːi
# Group with identifier 'aːu': aːu
# Group with identifier 'aːɪ': aːɪ
# Group with identifier 'aˤː': aˤː
# Group with identifier 'bvʷ': bvʷ
# Group with identifier 'bzʷ': bzʷ
# Group with identifier 'bʲː': bʲː
# Group with identifier 'bʷː': bʷː
# Group with identifier 'bˤː': bˤː
# Group with identifier 'ccʰ': ccʰ
# Group with identifier 'ccʷ': ccʷ
# Group with identifier 'ccʼ': ccʼ
# Group with identifier 'ccː': ccː
# Group with identifier 'cʰː': cʰː
# Group with identifier 'cʷʰ': cʷʰ
# Group with identifier 'cʼː': cʼː
# Group with identifier 'dlʷ': dlʷ
# Group with identifier 'dzʲ': dzʲ
# Group with identifier 'dzʷ': dzʷ
# Group with identifier 'dzː': dzː
# Group with identifier 'dzˠ': dzˠ
# Group with identifier 'dʑː': dʑː
# Group with identifier 'dʑᶣ': dʑᶣ
# Group with identifier 'dʒɾ': dʒɾ
# Group with identifier 'dʒʲ': dʒʲ
# Group with identifier 'dʒʷ': dʒʷ
# Group with identifier 'dʒː': dʒː
# Group with identifier 'dʒˠ': dʒˠ
# Group with identifier 'dːʑ': dːʑ
# Group with identifier 'dːʒ': dːʒ
# Group with identifier 'dˤː': dˤː
# Group with identifier 'eəɪ': eəɪ
# Group with identifier 'eːi': eːi
# Group with identifier 'fʲː': fʲː
# Group with identifier 'fʷː': fʷː
# Group with identifier 'iai': iai
# Group with identifier 'iau': iau
# Group with identifier 'iaː': iaː
# Group with identifier 'iei': iei
# Group with identifier 'ieu': ieu
# Group with identifier 'ieː': ieː
# Group with identifier 'ioi': ioi
# Group with identifier 'iou': iou
# Group with identifier 'ioː': ioː
# Group with identifier 'iui': iui
# Group with identifier 'iuo': iuo
# Group with identifier 'iuː': iuː
# Group with identifier 'iɑu': iɑu
# Group with identifier 'iəɪ': iəɪ
# Group with identifier 'iɛi': iɛi
# Group with identifier 'iɛː': iɛː
# Group with identifier 'iːe': iːe
# Group with identifier 'iːu': iːu
# Group with identifier 'iːə': iːə
# Group with identifier 'iːɛ': iːɛ
# Group with identifier 'iˤæ': iˤæ
# Group with identifier 'iˤː': iˤː
# Group with identifier 'kpr': kpr
# Group with identifier 'kpʰ': kpʰ
# Group with identifier 'kpʲ': kpʲ
# Group with identifier 'kpʷ': kpʷ
# Group with identifier 'kpː': kpː
# Group with identifier 'kpˤ': kpˤ
# Group with identifier 'kxʰ': kxʰ
# Group with identifier 'kxʷ': kxʷ
# Group with identifier 'kxʼ': kxʼ
# Group with identifier 'kxː': kxː
# Group with identifier 'kǀh': kǀh
# Group with identifier 'kǀx': kǀx
# Group with identifier 'kǀʔ': kǀʔ
# Group with identifier 'kǀʰ': kǀʰ
# Group with identifier 'kǀʷ': kǀʷ
# Group with identifier 'kǀʼ': kǀʼ
# Group with identifier 'kǁh': kǁh
# Group with identifier 'kǁx': kǁx
# Group with identifier 'kǁʔ': kǁʔ
# Group with identifier 'kǁʰ': kǁʰ
# Group with identifier 'kǁʼ': kǁʼ
# Group with identifier 'kǂh': kǂh
# Group with identifier 'kǂx': kǂx
# Group with identifier 'kǂʔ': kǂʔ
# Group with identifier 'kǂʰ': kǂʰ
# Group with identifier 'kǂˡ': kǂˡ
# Group with identifier 'kǃh': kǃh
# Group with identifier 'kǃx': kǃx
# Group with identifier 'kǃʔ': kǃʔ
# Group with identifier 'kǃʰ': kǃʰ
# Group with identifier 'kǃʼ': kǃʼ
# Group with identifier 'kʘh': kʘh
# Group with identifier 'kʘx': kʘx
# Group with identifier 'kʘʔ': kʘʔ
# Group with identifier 'kʘʰ': kʘʰ
# Group with identifier 'kʰː': kʰː
# Group with identifier 'kʷɾ': kʷɾ
# Group with identifier 'kʷʼ': kʷʼ
# Group with identifier 'kʷː': kʷː
# Group with identifier 'kʼː': kʼː
# Group with identifier 'lʲː': lʲː
# Group with identifier 'lˤː': lˤː
# Group with identifier 'mbv': mbv
# Group with identifier 'mbz': mbz
# Group with identifier 'mbɾ': mbɾ
# Group with identifier 'mbʲ': mbʲ
# Group with identifier 'mbʷ': mbʷ
# Group with identifier 'mbː': mbː
# Group with identifier 'mbˠ': mbˠ
# Group with identifier 'mpf': mpf
# Group with identifier 'mpɾ': mpɾ
# Group with identifier 'mpʰ': mpʰ
# Group with identifier 'mpʲ': mpʲ
# Group with identifier 'mpʷ': mpʷ
# Group with identifier 'mpʼ': mpʼ
# Group with identifier 'mʲː': mʲː
# Group with identifier 'mʷː': mʷː
# Group with identifier 'mˤː': mˤː
# Group with identifier 'ndl': ndl
# Group with identifier 'ndr': ndr
# Group with identifier 'ndz': ndz
# Group with identifier 'ndɮ': ndɮ
# Group with identifier 'ndʑ': ndʑ
# Group with identifier 'ndʒ': ndʒ
# Group with identifier 'ndʲ': ndʲ
# Group with identifier 'ndʷ': ndʷ
# Group with identifier 'ndː': ndː
# Group with identifier 'nsɾ': nsɾ
# Group with identifier 'nsʰ': nsʰ
# Group with identifier 'nsʷ': nsʷ
# Group with identifier 'nts': nts
# Group with identifier 'ntɕ': ntɕ
# Group with identifier 'ntɾ': ntɾ
# Group with identifier 'ntʃ': ntʃ
# Group with identifier 'ntʰ': ntʰ
# Group with identifier 'ntʷ': ntʷ
# Group with identifier 'ntʼ': ntʼ
# Group with identifier 'nzɾ': nzɾ
# Group with identifier 'nzʷ': nzʷ
# Group with identifier 'nɡɾ': nɡɾ
# Group with identifier 'nʃʷ': nʃʷ
# Group with identifier 'nʲː': nʲː
# Group with identifier 'nˤː': nˤː
# Group with identifier 'oaˤ': oaˤ
# Group with identifier 'oiˤ': oiˤ
# Group with identifier 'oəɪ': oəɪ
# Group with identifier 'oːu': oːu
# Group with identifier 'oːə': oːə
# Group with identifier 'pfʰ': pfʰ
# Group with identifier 'pfʼ': pfʼ
# Group with identifier 'pkʰ': pkʰ
# Group with identifier 'psʰ': psʰ
# Group with identifier 'psʷ': psʷ
# Group with identifier 'pʃʰ': pʃʰ
# Group with identifier 'pʃʼ': pʃʼ
# Group with identifier 'pʰː': pʰː
# Group with identifier 'pʲʰ': pʲʰ
# Group with identifier 'pʲʼ': pʲʼ
# Group with identifier 'pʲː': pʲː
# Group with identifier 'pʷʰ': pʷʰ
# Group with identifier 'pʷʼ': pʷʼ
# Group with identifier 'pʼː': pʼː
# Group with identifier 'pˤʰ': pˤʰ
# Group with identifier 'qǀʼ': qǀʼ
# Group with identifier 'qǁʼ': qǁʼ
# Group with identifier 'qǂʼ': qǂʼ
# Group with identifier 'qǃʼ': qǃʼ
# Group with identifier 'qʘʼ': qʘʼ
# Group with identifier 'qʼː': qʼː
# Group with identifier 'qˤʰ': qˤʰ
# Group with identifier 'qˤʼ': qˤʼ
# Group with identifier 'qχʰ': qχʰ
# Group with identifier 'qχʷ': qχʷ
# Group with identifier 'qχʼ': qχʼ
# Group with identifier 'qχː': qχː
# Group with identifier 'qχˤ': qχˤ
# Group with identifier 'rʲː': rʲː
# Group with identifier 'rˤː': rˤː
# Group with identifier 'sʲʰ': sʲʰ
# Group with identifier 'sʲː': sʲː
# Group with identifier 'sʷː': sʷː
# Group with identifier 'sʼː': sʼː
# Group with identifier 'sˤː': sˤː
# Group with identifier 'tsɦ': tsɦ
# Group with identifier 'tsʰ': tsʰ
# Group with identifier 'tsʲ': tsʲ
# Group with identifier 'tsʷ': tsʷ
# Group with identifier 'tsʼ': tsʼ
# Group with identifier 'tsː': tsː
# Group with identifier 'tsˠ': tsˠ
# Group with identifier 'tzʲ': tzʲ
# Group with identifier 'tɕʰ': tɕʰ
# Group with identifier 'tɕʷ': tɕʷ
# Group with identifier 'tɕʼ': tɕʼ
# Group with identifier 'tɕː': tɕː
# Group with identifier 'tɕᶣ': tɕᶣ
# Group with identifier 'tɬʰ': tɬʰ
# Group with identifier 'tɬʼ': tɬʼ
# Group with identifier 'tɬː': tɬː
# Group with identifier 'tʃx': tʃx
# Group with identifier 'tʃɾ': tʃɾ
# Group with identifier 'tʃʰ': tʃʰ
# Group with identifier 'tʃʲ': tʃʲ
# Group with identifier 'tʃʷ': tʃʷ
# Group with identifier 'tʃʼ': tʃʼ
# Group with identifier 'tʃː': tʃː
# Group with identifier 'tʃˠ': tʃˠ
# Group with identifier 'tʃˤ': tʃˤ
# Group with identifier 'tʰː': tʰː
# Group with identifier 'tʲʰ': tʲʰ
# Group with identifier 'tʲʼ': tʲʼ
# Group with identifier 'tʲː': tʲː
# Group with identifier 'tʷʰ': tʷʰ
# Group with identifier 'tʷʼ': tʷʼ
# Group with identifier 'tʼː': tʼː
# Group with identifier 'tːs': tːs
# Group with identifier 'tːɕ': tːɕ
# Group with identifier 'tːʃ': tːʃ
# Group with identifier 'tˤʰ': tˤʰ
# Group with identifier 'tˤʼ': tˤʼ
# Group with identifier 'tˤː': tˤː
# Group with identifier 'tθʰ': tθʰ
# Group with identifier 'tθʼ': tθʼ
# Group with identifier 'uai': uai
# Group with identifier 'uaː': uaː
# Group with identifier 'uei': uei
# Group with identifier 'ueu': ueu
# Group with identifier 'uie': uie
# Group with identifier 'uiɛ': uiɛ
# Group with identifier 'uoː': uoː
# Group with identifier 'uɑi': uɑi
# Group with identifier 'uɑ˞': uɑ˞
# Group with identifier 'uɔː': uɔː
# Group with identifier 'uəi': uəi
# Group with identifier 'uɛi': uɛi
# Group with identifier 'uːa': uːa
# Group with identifier 'uːe': uːe
# Group with identifier 'uːi': uːi
# Group with identifier 'uːə': uːə
# Group with identifier 'uːʌ': uːʌ
# Group with identifier 'uˤː': uˤː
# Group with identifier 'xʲː': xʲː
# Group with identifier 'xʷʼ': xʷʼ
# Group with identifier 'xʷː': xʷː
# Group with identifier 'yia': yia
# Group with identifier 'yœː': yœː
# Group with identifier 'yːə': yːə
# Group with identifier 'zʲː': zʲː
# Group with identifier 'zˤː': zˤː
# Group with identifier 'æːʊ': æːʊ
# Group with identifier 'øːy': øːy
# Group with identifier 'ŋhʲ': ŋhʲ
# Group with identifier 'ŋhʷ': ŋhʷ
# Group with identifier 'ŋhᶣ': ŋhᶣ
# Group with identifier 'ŋkx': ŋkx
# Group with identifier 'ŋkɾ': ŋkɾ
# Group with identifier 'ŋkʰ': ŋkʰ
# Group with identifier 'ŋkʲ': ŋkʲ
# Group with identifier 'ŋkʷ': ŋkʷ
# Group with identifier 'ŋkʼ': ŋkʼ
# Group with identifier 'ŋmʲ': ŋmʲ
# Group with identifier 'ŋmʷ': ŋmʷ
# Group with identifier 'ŋmˤ': ŋmˤ
# Group with identifier 'ŋxʰ': ŋxʰ
# Group with identifier 'ŋǀʰ': ŋǀʰ
# Group with identifier 'ŋǀˀ': ŋǀˀ
# Group with identifier 'ŋǁʰ': ŋǁʰ
# Group with identifier 'ŋǁʼ': ŋǁʼ
# Group with identifier 'ŋǂʰ': ŋǂʰ
# Group with identifier 'ŋǂˀ': ŋǂˀ
# Group with identifier 'ŋǂˡ': ŋǂˡ
# Group with identifier 'ŋǃʰ': ŋǃʰ
# Group with identifier 'ŋǃʼ': ŋǃʼ
# Group with identifier 'ŋɡǃ': ŋɡǃ
# Group with identifier 'ŋɡʲ': ŋɡʲ
# Group with identifier 'ŋɡʷ': ŋɡʷ
# Group with identifier 'ŋɡː': ŋɡː
# Group with identifier 'ŋɣʲ': ŋɣʲ
# Group with identifier 'ŋɣʷ': ŋɣʷ
# Group with identifier 'ŋɣᶣ': ŋɣᶣ
# Group with identifier 'ŋʷː': ŋʷː
# Group with identifier 'œyː': œyː
# Group with identifier 'ɑuː': ɑuː
# Group with identifier 'ɑːi': ɑːi
# Group with identifier 'ɒːi': ɒːi
# Group with identifier 'ɔaː': ɔaː
# Group with identifier 'ɔuː': ɔuː
# Group with identifier 'ɔyː': ɔyː
# Group with identifier 'ɔːi': ɔːi
# Group with identifier 'ɔːə': ɔːə
# Group with identifier 'ɔˤː': ɔˤː
# Group with identifier 'ɖʐʷ': ɖʐʷ
# Group with identifier 'əɪa': əɪa
# Group with identifier 'əʊɪ': əʊɪ
# Group with identifier 'ɛiː': ɛiː
# Group with identifier 'ɛæː': ɛæː
# Group with identifier 'ɛːi': ɛːi
# Group with identifier 'ɟʝʷ': ɟʝʷ
# Group with identifier 'ɟʝː': ɟʝː
# Group with identifier 'ɡbr': ɡbr
# Group with identifier 'ɡbʲ': ɡbʲ
# Group with identifier 'ɡbʷ': ɡbʷ
# Group with identifier 'ɡbː': ɡbː
# Group with identifier 'ɡbˤ': ɡbˤ
# Group with identifier 'ɡǀx': ɡǀx
# Group with identifier 'ɡǁx': ɡǁx
# Group with identifier 'ɡǂx': ɡǂx
# Group with identifier 'ɡǂˡ': ɡǂˡ
# Group with identifier 'ɡǃx': ɡǃx
# Group with identifier 'ɡʘx': ɡʘx
# Group with identifier 'ɡʷː': ɡʷː
# Group with identifier 'ɢʷˤ': ɢʷˤ
# Group with identifier 'ɪɛː': ɪɛː
# Group with identifier 'ɬʲʼ': ɬʲʼ
# Group with identifier 'ɬʷː': ɬʷː
# Group with identifier 'ɱfɾ': ɱfɾ
# Group with identifier 'ɱfʲ': ɱfʲ
# Group with identifier 'ɱfʷ': ɱfʷ
# Group with identifier 'ɱvɾ': ɱvɾ
# Group with identifier 'ɱvʲ': ɱvʲ
# Group with identifier 'ɲcʰ': ɲcʰ
# Group with identifier 'ɲcʼ': ɲcʼ
# Group with identifier 'ɲdʑ': ɲdʑ
# Group with identifier 'ɲɟʑ': ɲɟʑ
# Group with identifier 'ɲɟʝ': ɲɟʝ
# Group with identifier 'ɳɖr': ɳɖr
# Group with identifier 'ɳɖɽ': ɳɖɽ
# Group with identifier 'ɳɖʐ': ɳɖʐ
# Group with identifier 'ɳɡʷ': ɳɡʷ
# Group with identifier 'ɳʈr': ɳʈr
# Group with identifier 'ɳʈʂ': ɳʈʂ
# Group with identifier 'ɳʈʰ': ɳʈʰ
# Group with identifier 'ɴqʰ': ɴqʰ
# Group with identifier 'ʁʷː': ʁʷː
# Group with identifier 'ʃʲː': ʃʲː
# Group with identifier 'ʃʷː': ʃʷː
# Group with identifier 'ʃʼː': ʃʼː
# Group with identifier 'ʈʂʰ': ʈʂʰ
# Group with identifier 'ʈʂʷ': ʈʂʷ
# Group with identifier 'ʈʂʼ': ʈʂʼ
# Group with identifier 'ʈʂː': ʈʂː
# Group with identifier 'ʈʰː': ʈʰː
# Group with identifier 'ʊaɪ': ʊaɪ
# Group with identifier 'ʊˤː': ʊˤː
# Group with identifier 'ʒʲː': ʒʲː
# Group with identifier 'ʒˤː': ʒˤː
# Group with identifier 'ʔŋǀ': ʔŋǀ
# Group with identifier 'ʔŋǁ': ʔŋǁ
# Group with identifier 'ʔŋǂ': ʔŋǂ
# Group with identifier 'ʔŋǃ': ʔŋǃ
# Group with identifier 'ʔŋʘ': ʔŋʘ
# Group with identifier 'ʔʲː': ʔʲː
# Group with identifier 'ˀkp': ˀkp
# Group with identifier 'ˀts': ˀts
# Group with identifier 'ˀtɬ': ˀtɬ
# Group with identifier 'ˀɡb': ˀɡb
# Group with identifier '˥˧˥': ˥˧˥
# Group with identifier '˧˨ˤ': ˧˨ˤ
# Group with identifier 'βʲː': βʲː
# Group with identifier 'χʼː': χʼː
# Group with identifier 'ccʷʰ': ccʷʰ
# Group with identifier 'dʒxʼ': dʒxʼ
# Group with identifier 'iuaː': iuaː
# Group with identifier 'kxʰː': kxʰː
# Group with identifier 'kxʷʰ': kxʷʰ
# Group with identifier 'kxʼː': kxʼː
# Group with identifier 'kǀxʼ': kǀxʼ
# Group with identifier 'kǀʷʰ': kǀʷʰ
# Group with identifier 'kǁxʰ': kǁxʰ
# Group with identifier 'kǁxʼ': kǁxʼ
# Group with identifier 'kǂˡx': kǂˡx
# Group with identifier 'kǃxʰ': kǃxʰ
# Group with identifier 'kǃxʼ': kǃxʼ
# Group with identifier 'kʷʰː': kʷʰː
# Group with identifier 'mpfʼ': mpfʼ
# Group with identifier 'ndzʲ': ndzʲ
# Group with identifier 'ndzʷ': ndzʷ
# Group with identifier 'ndʒʷ': ndʒʷ
# Group with identifier 'ntsʰ': ntsʰ
# Group with identifier 'ntsʼ': ntsʼ
# Group with identifier 'ntɕʰ': ntɕʰ
# Group with identifier 'ntʃɾ': ntʃɾ
# Group with identifier 'ntʃʰ': ntʃʰ
# Group with identifier 'ntʃʷ': ntʃʷ
# Group with identifier 'ntʃʼ': ntʃʼ
# Group with identifier 'psʷʰ': psʷʰ
# Group with identifier 'qʷˤʰ': qʷˤʰ
# Group with identifier 'qʷˤʼ': qʷˤʼ
# Group with identifier 'qχʰː': qχʰː
# Group with identifier 'qχʷʼ': qχʷʼ
# Group with identifier 'qχʷˤ': qχʷˤ
# Group with identifier 'qχʼː': qχʼː
# Group with identifier 'qχˤʼ': qχˤʼ
# Group with identifier 'qχˤː': qχˤː
# Group with identifier 'tsʰː': tsʰː
# Group with identifier 'tsʲʰ': tsʲʰ
# Group with identifier 'tsʲʼ': tsʲʼ
# Group with identifier 'tsʲː': tsʲː
# Group with identifier 'tsʷʰ': tsʷʰ
# Group with identifier 'tsʷʼ': tsʷʼ
# Group with identifier 'tsʷː': tsʷː
# Group with identifier 'tsʼː': tsʼː
# Group with identifier 'tsˤʰ': tsˤʰ
# Group with identifier 'tɕʰː': tɕʰː
# Group with identifier 'tɬʰː': tɬʰː
# Group with identifier 'tɬʷʰ': tɬʷʰ
# Group with identifier 'tɬʷʼ': tɬʷʼ
# Group with identifier 'tɬʼː': tɬʼː
# Group with identifier 'tʃʰː': tʃʰː
# Group with identifier 'tʃʲʰ': tʃʲʰ
# Group with identifier 'tʃʲː': tʃʲː
# Group with identifier 'tʃʷʰ': tʃʷʰ
# Group with identifier 'tʃʷʼ': tʃʷʼ
# Group with identifier 'tʃʷː': tʃʷː
# Group with identifier 'tʃʼː': tʃʼː
# Group with identifier 'tʃˤʰ': tʃˤʰ
# Group with identifier 'tʃˤʼ': tʃˤʼ
# Group with identifier 'ŋmkp': ŋmkp
# Group with identifier 'ŋmɡb': ŋmɡb
# Group with identifier 'ŋǀxˀ': ŋǀxˀ
# Group with identifier 'ŋǂxˀ': ŋǂxˀ
# Group with identifier 'ŋɡmb': ŋɡmb
# Group with identifier 'ɡǀkʰ': ɡǀkʰ
# Group with identifier 'ɡǀxʼ': ɡǀxʼ
# Group with identifier 'ɡǁkʰ': ɡǁkʰ
# Group with identifier 'ɡǁxʼ': ɡǁxʼ
# Group with identifier 'ɡǂkʰ': ɡǂkʰ
# Group with identifier 'ɡǂˡx': ɡǂˡx
# Group with identifier 'ɡǃkʰ': ɡǃkʰ
# Group with identifier 'ɡǃxʼ': ɡǃxʼ
# Group with identifier 'ɡʘkʰ': ɡʘkʰ
# Group with identifier 'ɢǀqʰ': ɢǀqʰ
# Group with identifier 'ɢǁqʰ': ɢǁqʰ
# Group with identifier 'ɢǃqʰ': ɢǃqʰ
# Group with identifier 'ɲtɕʰ': ɲtɕʰ
# Group with identifier 'ɳʈʂʰ': ɳʈʂʰ
# Group with identifier '˥˩˩˥': ˥˩˩˥
# Group with identifier 'kǀkxʼ': kǀkxʼ
# Group with identifier 'kǁkxʼ': kǁkxʼ
# Group with identifier 'kǂkxʼ': kǂkxʼ
# Group with identifier 'kǃkxʼ': kǃkxʼ
# Group with identifier 'kʘkxʼ': kʘkxʼ
# Group with identifier 'pʼkxʼ': pʼkxʼ
# Group with identifier 'qχʷˤʼ': qχʷˤʼ
# Group with identifier 'tʼkxʼ': tʼkxʼ
# Group with identifier 'ŋmkpɾ': ŋmkpɾ
# Group with identifier 'ŋǂˡxˀ': ŋǂˡxˀ
# Group with identifier 'ɡǀkxʼ': ɡǀkxʼ
# Group with identifier 'ɡǁkxʼ': ɡǁkxʼ
# Group with identifier 'ɡǂkxʼ': ɡǂkxʼ
# Group with identifier 'ɡǃkxʼ': ɡǃkxʼ
# Group with identifier 'ɡʘkxʼ': ɡʘkxʼ
# 1158
# 1158

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

                     
choice = 1


def fontSize(n):
    if n >= 300:
        return 3
    else: 
        return 10

# Compute Distances and store them in a matrix
n = len(array_of_strings)
distance_matrix = np.zeros((n, n), dtype=float)

for i in range(n):
    for j in range(n):
        #plt.text(j, i, str(distance_matrix[i, j]), ha='center', va='center', color='black')
        distance_matrix[i, j] = distance(array_of_strings[i], array_of_strings[j])

        #distance_matrix[i, j] = distance(array_of_strings[i], array_of_strings[j])

# Create a DataFrame for better visualization
distance_df = pd.DataFrame(distance_matrix, columns=array_of_strings, index=array_of_strings)

# Create a heatmap for the distance matrix
plt.figure(figsize=(8, 8), dpi=600)

cax = plt.matshow(distance_df, cmap='coolwarm', aspect='auto')
plt.colorbar(cax)

# Customize the plot (optional)
plt.xticks(np.arange(n), array_of_strings, rotation=45)
plt.yticks(np.arange(n), array_of_strings)
plt.rcParams['xtick.labelsize'] = 2  # Adjust the font size for x-axis tick labels
plt.rcParams['ytick.labelsize'] = 2 
plt.title('Distance Matrix')


plt.savefig('heatmap1.png', dpi=1600, bbox_inches='tight')
# Display the plot
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

                     
choice = 1
from scipy.cluster.hierarchy import linkage, dendrogram
from scipy.spatial.distance import squareform

# Perform hierarchical clustering
linked = linkage(squareform(distance_matrix), method='complete', metric='euclidean')

# Create a dendrogram to visualize the clustering
plt.figure(figsize=(16, 26))
dendrogram(linked, orientation='right', labels=array_of_strings)
plt.title('Hierarchical Clustering Dendrogram')
if exportImages:
    plt.savefig('DendrogramSort.png', dpi=1200, bbox_inches='tight')
plt.show()

# Reorder the distance matrix based on the clustering
order = dendrogram(linked, no_plot=True)['leaves']
distance_df = distance_df.iloc[order, order]

# Create a heatmap for the reordered distance matrix
plt.figure(figsize=(16, 16))
cax = plt.matshow(distance_df, cmap='coolwarm', aspect='auto')
plt.colorbar(cax)

# Customize the plot (optional)
plt.xticks(np.arange(n), distance_df.columns, rotation=45)
plt.yticks(np.arange(n), distance_df.index)
plt.rcParams['xtick.labelsize'] = fontSize(len(paradigms))  # Adjust the font size for x-axis tick labels
plt.rcParams['ytick.labelsize'] = fontSize(len(paradigms)) 
plt.title('Distance Matrix (Clustered)')

if exportImages:
    plt.savefig('heatmapSort.png', dpi=3200, bbox_inches='tight')
# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[121], line 15
#      13 # Create a dendrogram to visualize the clustering
#      14 plt.figure(figsize=(16, 16))
# ---> 15 dendrogram(linked, orientation='right', labels=array_of_strings)
#      16 plt.title('Hierarchical Clustering Dendrogram')
#      17 if exportImages:
#
# File C:\Apps\anaconda3\Lib\site-packages\scipy\cluster\hierarchy.py:3304, in dendrogram(Z, p, truncate_mode, color_threshold, get_leaves, orientation, labels, count_sort, distance_sort, show_leaf_counts, no_plot, no_labels, leaf_font_size, leaf_rotation, leaf_label_func, show_contracted, link_color_func, ax, above_threshold_color)
#    3300     raise ValueError("orientation must be one of 'top', 'left', "
#    3301                      "'bottom', or 'right'")
#    3303 if labels is not None and Z.shape[0] + 1 != len(labels):
# -> 3304     raise ValueError("Dimensions of Z and labels must be consistent.")
#    3306 is_valid_linkage(Z, throw=True, name='Z')
#    3307 Zs = Z.shape
#
# ValueError: Dimensions of Z and labels must be consistent.

# %% [markdown]
# # Audio Stuff
# https://musicinformationretrieval.com/ipython_audio.html
